# %% [markdown]
# <a href="https://colab.research.google.com/github/ivydabiero/dsc-phase-1-project/blob/master/assignment_on_the_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
Data = pd.read_excel(r'/content/drive/MyDrive/movies/bom.movie_gross.xlsx')

# %%
display(pd.DataFrame(Data))
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#       foreign_gross  year
# ...

# %%
data = pd.DataFrame(Data)

# %% [markdown]
# in this question we will Produce summary statistics, visualizations, and interpretive text describing the distributions of SalePrice, TotRmsAbvGrd, and OverallCond

# %%
# compare the year against the number of movies produced in that year
from matplotlib import pyplot as plt
_df_2['year'].plot(kind='hist', bins=20, title='year')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#compare the years agaist the number of movies using a line graph
from matplotlib import pyplot as plt
_df_10['year'].plot(kind='line', figsize=(8, 4), title='year')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
#comapare the amount of money as domestic gross against the number of years that that the movies were produced
from matplotlib import pyplot as plt
_df_8['domestic_gross'].plot(kind='hist', figsize=(8, 4), title='domestic_gross')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_0['domestic_gross'].plot(kind='hist', bins=20, title='domestic_gross')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#compare the the difference between foreign_gross and the domestic_gross using the scattered graph
from matplotlib import pyplot as plt
_df_3.plot(kind='scatter', x='domestic_gross', y='foreign_gross', s=32, alpha=.8)
plt.gca().spines[['right', 'top',]].set_visible(False)

# %%
# compare the year against the amount of foreign_gross that was earned during those years
from matplotlib import pyplot as plt
_df_4.plot(kind='scatter', x='foreign_gross', y='year', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# in this section I will produce the Differences between Subsets

# %%
# seperating data into different subsets based on overallcond
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(Data, test_size=0.2, random_state=42)

# %%
train_data = pd.DataFrame(train_data)

# %%
#describe the data so that we know the type of data we have
pd.DataFrame(Data).describe()
# Out:
#        domestic_gross  foreign_gross         year
# count    3.359000e+03   2.037000e+03  3387.000000
# mean     2.874585e+07   7.487281e+07  2013.958075
# std      6.698250e+07   1.374106e+08     2.478141
# min      1.000000e+02   6.000000e+02  2010.000000
# 25%      1.200000e+05   3.700000e+06  2012.000000
# 50%      1.400000e+06   1.870000e+07  2014.000000
# 75%      2.790000e+07   7.490000e+07  2016.000000
# max      9.367000e+08   9.605000e+08  2018.000000

# %%
#how to split the impacts the ditribution of domestic gross
data['Sales_price'] = pd.cut(data['domestic_gross'],
                              bins= [1, 2,3,4.5,6,8,10],
                              labels = [1,2,3,4,5,6,])

# %%
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(Data, test_size=0.2, random_state=42)

# %%
train_data['Sales_price']=pd.value_counts(train_data['domestic_gross'])/len(train_data)
train_data['Sales_price']
# Out:
# 2025   NaN
# 3205   NaN
# 2912   NaN
# 1373   NaN
# 2633   NaN
#         ..
# 1095   NaN
# 1130   NaN
# 1294   NaN
# 860    NaN
# 3174   NaN
# Name: Sales_price, Length: 2709, dtype: float64

# %%
import pandas as pd

# Sample DataFrame
data = {
    'YearBuilt': [2000, 1995, 2010, 1980, 2005,2003,2004,],
    'YearSold': [2011, 2012, 2013, 2014, 2016, 2017,2018],
    'SalePrice': [250000, 200000, 180000, 300000, 280000, 260000,240000]
}

df = pd.DataFrame(data)

# Create the Age feature of the movies
df['Age'] = df['YearSold'] - df['YearBuilt']

# Display the DataFrame
print(df)
# Out:
#    YearBuilt  YearSold  SalePrice  Age
# 0       2000      2011     250000   11
# 1       1995      2012     200000   17
# 2       2010      2013     180000    3
# 3       1980      2014     300000   34
# 4       2005      2016     280000   11
# 5       2003      2017     260000   14
# 6       2004      2018     240000   14

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {
    'YearBuilt': [2000, 1995, 2010, 1980, 2005,2003,2004,],
    'YearSold': [2011, 2012, 2013, 2014, 2016, 2017,2018],
    'SalePrice': [250000, 200000, 180000, 300000, 280000, 260000,240000]
}

# Create DataFrame
df = pd.DataFrame(data)

# Create new feature Age
df['Age'] = df['YearSold'] - df['YearBuilt']

# Plot the relationship between Age and SalePrice
plt.figure(figsize=(10, 6))
plt.scatter(df['Age'], df['SalePrice'], alpha=0.6)
plt.title('Relationship between Age and Sale Price')
plt.xlabel('Age of the Movies (years)')
plt.ylabel('Sale Price ($)')
plt.grid(True)
plt.show()
